# %%
import pandas as pd
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv("diabetes.csv", header=None, names=col_names)

# %%
pima.head()
# Out:
#       pregnant  glucose             bp           skin  insulin   bmi  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                    pedigree  age    label
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load dataset
df = pd.read_csv('diabetes.csv')

# Features and target
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=16, test_size=0.2)

# Train model
logreg = LogisticRegression(max_iter=1000, random_state=16)
logreg.fit(X_train, y_train)

# Predict & evaluate
y_pred = logreg.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Load data
df = pd.read_csv('diabetes.csv')

# Select a single feature for visualization (e.g., Glucose)
X = df[['Glucose']]
X=df[['BloodPressure']]
X=df[['SkinThickness']]
X=df[['Insulin']]
X=df[['BMI']]
y = df['Outcome']

# Train logistic regression
model = LogisticRegression()
model.fit(X, y)

# Generate values for prediction
X_test_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test_vals)[:, 1]

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='black', label='Data')
plt.plot(X_test_vals, y_prob, color='Brown', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Glucose')
plt.ylabel('Probability of Diabetes')
plt.title('Logistic Regression Sigmoid Curve (Glucose vs Outcome)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/gaganngaware/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Load data
df = pd.read_csv('diabetes.csv')

# Select a single feature for visualization (e.g., Glucose)

X=df[['SkinThickness']]

y = df['Outcome']

# Train logistic regression
model = LogisticRegression()
model.fit(X, y)

# Generate values for prediction
X_test_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test_vals)[:, 1]

# Plot
plt.figure(figsize=(6, 9))
plt.scatter(X, y, color='black', label='Data')
plt.plot(X_test_vals, y_prob, color='Purple', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Glucose')
plt.ylabel('Probability of Diabetes')
plt.title('Logistic Regression Sigmoid Curve (Glucose vs Outcome)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/gaganngaware/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Load data
df = pd.read_csv('diabetes.csv')

# Select a single feature for visualization (e.g., Glucose)


X=df[['BloodPressure']]
y = df['Outcome']

# Train logistic regression
model = LogisticRegression()
model.fit(X, y)

# Generate values for prediction
X_test_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test_vals)[:, 1]

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='black', label='Data')
plt.plot(X_test_vals, y_prob, color='Orange', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Glucose')
plt.ylabel('Probability of Diabetes')
plt.title('Logistic Regression Sigmoid Curve (Glucose vs Outcome)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/gaganngaware/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Load data
df = pd.read_csv('diabetes.csv')

# Select a single feature for visualization (e.g., Glucose)

X=df[['BMI']]

y = df['Outcome']

# Train logistic regression
model = LogisticRegression()
model.fit(X, y)

# Generate values for prediction
X_test_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test_vals)[:, 1]

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='black', label='Data')
plt.plot(X_test_vals, y_prob, color='Blue', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Glucose')
plt.ylabel('Probability of Diabetes')
plt.title('Logistic Regression Sigmoid Curve (Glucose vs Outcome)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/gaganngaware/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Load data
df = pd.read_csv('diabetes.csv')

# Select a single feature for visualization (e.g., Glucose)

X=df[['Pregnancies']]

y = df['Outcome']

# Train logistic regression
model = LogisticRegression()
model.fit(X, y)

# Generate values for prediction
X_test_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test_vals)[:, 1]

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='black', label='Data')
plt.plot(X_test_vals, y_prob, color='Yellow', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Glucose')
plt.ylabel('Probability of Diabetes')
plt.title('Logistic Regression Sigmoid Curve (Glucose vs Outcome)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/gaganngaware/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Load data
df = pd.read_csv('diabetes.csv')

# Select a single feature for visualization (e.g., Glucose)

X=df[['Age']]

y = df['Outcome']

# Train logistic regression
model = LogisticRegression()
model.fit(X, y)

# Generate values for prediction
X_test_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test_vals)[:, 1]

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='black', label='Data')
plt.plot(X_test_vals, y_prob, color='Black', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Glucose')
plt.ylabel('Probability of Diabetes')
plt.title('Logistic Regression Sigmoid Curve (Glucose vs Outcome)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/gaganngaware/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(random_state=16)

# fit the model with data
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

# %%
# import the metrics class
from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[125,   0],
#        [ 67,   0]])

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion Matrix', y=1.1)
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted Label')
